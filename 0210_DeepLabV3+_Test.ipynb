# %% [markdown]
# <a href="https://colab.research.google.com/github/sooo19/A-study-of-the-data-generation-model-of-the-Folk-Painting-source-data/blob/main/0210_DeepLabV3%2B_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Colab_Gdrive 연동
from google.colab import drive 
drive.mount('/content/gdrive/')
# Out:
# Mounted at /content/gdrive/

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
tf.__version__
# Out:
# '1.15.2'

# %% [markdown]
# TEST

# %%
import os
from os.path import expanduser
import tensorflow as tf 
from io import BytesIO
import tarfile
import tempfile
from six.moves import urllib

home = expanduser("~")
os.chdir(home)

os.chdir('/content/gdrive/MyDrive/deeplabmodels'+'/research/')

# %%
# !ls
# Out:
# adversarial_text    cvt_text	   lfads		  README.md
# attention_ocr	    deeplab	   lstm_object_detection  rebar
# audioset	    deep_speech    marco		  seq_flow_lite
# autoaugment	    delf	   nst_blogpost		  slim
# build		    dist	   object_detection	  slim.egg-info
# cognitive_planning  efficient-hrl  pcl_rl		  vid2depth

# %%
os.chdir('/content/gdrive/MyDrive/deeplabmodels'+'/research/') #os.chdir('/content/gdrive/MyDrive/deeplabmodels'+'/research/')
# !export PYTHONPATH=$PYTHONPATH:`pwd`:`pwd`/slim
# !cp -r slim/* deeplab

# %%
os.chdir('/content/gdrive/MyDrive/deeplabmodels'+'/research/')
# !python slim/setup.py build
# !python slim/setup.py install
# Out:
# running build
# running build_py
# copying deeplab/download_and_convert_data.py -> build/lib/deeplab
# copying deeplab/eval_image_classifier.py -> build/lib/deeplab
# copying deeplab/export_inference_graph.py -> build/lib/deeplab
# copying deeplab/__init__.py -> build/lib/deeplab
# copying deeplab/export_inference_graph_test.py -> build/lib/deeplab
# copying deeplab/setup.py -> build/lib/deeplab
# copying deeplab/train_image_classifier.py -> build/lib/deeplab
# copying deeplab/datasets/dataset_factory.py -> build/lib/deeplab/datasets
# copying deeplab/datasets/__init__.py -> build/lib/deeplab/datasets
# copying deeplab/datasets/cifar10.py -> build/lib/deeplab/datasets
# copying deeplab/datasets/dataset_utils.py -> build/lib/deeplab/datasets
# copying deeplab/datasets/download_and_convert_cifar10.py -> build/lib/deeplab/datasets
# copying deeplab/datasets/build_imagenet_data.py -> build/lib/deeplab/datasets
# ...

# %%
os.chdir('/content/gdrive/MyDrive/deeplabmodels/research/deeplab')

# %%
# !sh /content/gdrive/MyDrive/deeplabmodels/research/deeplab/local_test.sh
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#     aspp2_depthwise/BatchNorm (--/4.10k params)
#       aspp2_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp2_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp2_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp2_pointwise (--/524.80k params)
#     aspp2_pointwise/BatchNorm (--/512 params)
#       aspp2_pointwise/BatchNorm/beta (256, 256/256 params)
#       aspp2_pointwise/BatchNorm/gamma (256, 256/256 params)
#     aspp2_pointwise/weights (1x1x2048x256, 524.29k/524.29k params)
#   aspp3_depthwise (--/22.53k params)
#     aspp3_depthwise/BatchNorm (--/4.10k params)
#       aspp3_depthwise/BatchNorm/beta (2048, 2.05k/2.05k params)
#       aspp3_depthwise/BatchNorm/gamma (2048, 2.05k/2.05k params)
#     aspp3_depthwise/depthwise_weights (3x3x2048x1, 18.43k/18.43k params)
#   aspp3_pointwise (--/524.80k params)
#     aspp3_pointwise/BatchNorm (--/512 params)
# ...
